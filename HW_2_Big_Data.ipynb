# %% [markdown]
# <a href="https://colab.research.google.com/github/KathyLi77/My-Code/blob/main/HW_2_Big_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q1 Find in which directory in Hadoop within "/user/dmitri" I stored files that match a pattern of “class_2_data_*”

# %% [markdown]
# Code: $ hadoop fs -find /user/dmitri -name "class_2_data_*"
# Answer: /user/dmitri/cities

# %% [markdown]
# # Q2 Get files from HDFS into Linux

# %% [markdown]
# Code: hadoop fs -getmerge /user/dmitri/cities /home/jiaqili/merged_file.csv

# %% [markdown]
# # Q3 Download a single Linux file into your laptop

# %% [markdown]
# Code: scp jiaqili@34.173.32.254:/home/jiaqili/merged_file.csv /Users/a../Downloads

# %% [markdown]
# # Q4 On your laptop use Python to:
# ## Parse CSVs
# ## Summarize all values for “Chicago” variable - one single number across all files (total SUM of the numbers in Chicago column)

# %%
from google.colab import files
import pandas as pd

# %%
df = files.upload()
# Out:
#      <input type="file" id="files-4520f30d-be7d-4b47-b4fc-5496dee6c075" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4520f30d-be7d-4b47-b4fc-5496dee6c075">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = list(df.keys())[0]

# %%
df_cities = pd.read_csv(file_name)

# %%
df_cities.head()
# Out:
#   Chicago London Helsinki Dubai
# 0      18     52       20    57
# 1      86     42        0    68
# 2      59     70       28    34
# 3      72      3       14    61
# 4      75     43       41    19

# %%
# find sum
sum_chicago=df_cities["Chicago"].sum()

# %%
sum_chicago
# Out:
# '...'
